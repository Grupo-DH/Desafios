# %%
import pandas as pd
pd.read_csv('https://www.dropbox.com/s/5f0uvdn1h9j1fgo/DM_CURSO.CSV?dl=1', sep='|', encoding='latin1')
# Out:
#      NU_ANO_CENSO  CO_IES  TP_CATEGORIA_ADMINISTRATIVA  \
# 0            2017     789                            1
# 1            2017    4567                            5
# 2            2017    2341                            4
# 3            2017     670                            5
# 4            2017     403                            5
# ..            ...     ...                          ...
# 995          2017     910                            5
# 996          2017      57                            2
# 997          2017    1702                            4
# 998          2017      13                            5
# 999          2017     671                            4
#
#      TP_ORGANIZACAO_ACADEMICA  CO_LOCAL_OFERTA  CO_UF  CO_MUNICIPIO  \
# 0                           1        1033528.0   14.0     1400100.0
# 1                           3         659871.0   51.0     5107925.0
# 2                           3         131728.0   35.0     3510609.0
# ...
